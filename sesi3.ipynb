# %%
from Bio.Seq import Seq

# %%
coding_strand  = Seq('ATGATCTCGTAA')
print(coding_strand)
# Out:
# ATGATCTCGTAA

# %%
template_strand  = coding_strand.complement()
print(template_strand)
# Out:
# TACTAGAGCATT

# %%
#transcribe ngubah T jadi U
mRNA = coding_strand.transcribe()
print(mRNA)
# Out:
# AUGAUCUCGUAA

# %%
#back transcribe -> ngubah semua u jadi t
ToDNA = mRNA.back_transcribe()
print(ToDNA)
# Out:
# ATGATCTCGTAA

# %%
# translate _> ngubah satu kodon menjadi asam amino

amino_acid = mRNA.translate()
print(amino_acid)
# Out:
# MIS*

# %%
from Bio.SeqUtils import seq3, seq1

# %%
protein_name = seq3(amino_acid)
print(protein_name)
print(seq1(protein_name))
# Out:
# MetIleSerTer
# MIS*

# %%
from Bio.Data import CodonTable

# %%
print(CodonTable.unambiguous_dna_by_name['Standard'])
# Out:
# Table 1 Standard, SGC0
#
#   |  T      |  C      |  A      |  G      |
# --+---------+---------+---------+---------+--
# T | TTT F   | TCT S   | TAT Y   | TGT C   | T
# T | TTC F   | TCC S   | TAC Y   | TGC C   | C
# T | TTA L   | TCA S   | TAA Stop| TGA Stop| A
# T | TTG L(s)| TCG S   | TAG Stop| TGG W   | G
# --+---------+---------+---------+---------+--
# C | CTT L   | CCT P   | CAT H   | CGT R   | T
# C | CTC L   | CCC P   | CAC H   | CGC R   | C
# C | CTA L   | CCA P   | CAA Q   | CGA R   | A
# C | CTG L(s)| CCG P   | CAG Q   | CGG R   | G
# --+---------+---------+---------+---------+--
# A | ATT I   | ACT T   | AAT N   | AGT S   | T
# A | ATC I   | ACC T   | AAC N   | AGC S   | C
# A | ATA I   | ACA T   | AAA K   | AGA R   | A
# A | ATG M(s)| ACG T   | AAG K   | AGG R   | G
# --+---------+---------+---------+---------+--
# G | GTT V   | GCT A   | GAT D   | GGT G   | T
# G | GTC V   | GCC A   | GAC D   | GGC G   | C
# G | GTA V   | GCA A   | GAA E   | GGA G   | A
# G | GTG V   | GCG A   | GAG E   | GGG G   | G
# --+---------+---------+---------+---------+--

# %%
print(CodonTable.ambiguous_rna_by_name['Standard'])
# Out:
# Table 1 Standard, SGC0
#
#   |  U      |  C      |  A      |  G      |
# --+---------+---------+---------+---------+--
# U | UUU F   | UCU S   | UAU Y   | UGU C   | U
# U | UUC F   | UCC S   | UAC Y   | UGC C   | C
# U | UUA L   | UCA S   | UAA Stop| UGA Stop| A
# U | UUG L(s)| UCG S   | UAG Stop| UGG W   | G
# --+---------+---------+---------+---------+--
# C | CUU L   | CCU P   | CAU H   | CGU R   | U
# C | CUC L   | CCC P   | CAC H   | CGC R   | C
# C | CUA L   | CCA P   | CAA Q   | CGA R   | A
# C | CUG L(s)| CCG P   | CAG Q   | CGG R   | G
# --+---------+---------+---------+---------+--
# A | AUU I   | ACU T   | AAU N   | AGU S   | U
# A | AUC I   | ACC T   | AAC N   | AGC S   | C
# A | AUA I   | ACA T   | AAA K   | AGA R   | A
# A | AUG M(s)| ACG T   | AAG K   | AGG R   | G
# --+---------+---------+---------+---------+--
# G | GUU V   | GCU A   | GAU D   | GGU G   | U
# G | GUC V   | GCC A   | GAC D   | GGC G   | C
# G | GUA V   | GCA A   | GAA E   | GGA G   | A
# G | GUG V   | GCG A   | GAG E   | GGG G   | G
# --+---------+---------+---------+---------+--

# %%
import py3Dmol

# %%
viewmol = py3Dmol.view(query='pdb:7ET1')
viewmol.setStyle({'cartoon': {'color':'spectrum'}})
viewmol.show()
# Out:
# <div id="3dmolviewer_174191537193227"  style="position: relative; width: 640px; height: 480px;">
#         <p id="3dmolwarning_174191537193227" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.2.0/3Dmol-min.js');
# }
#
# var viewer_174191537193227 = null;
# var warn = document.getElementById("3dmolwarning_174191537193227");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_174191537193227 = $3Dmol.createViewer(document.getElementById("3dmolviewer_174191537193227"),{backgroundColor:"white"});
# $3Dmol.download("pdb:7ET1", viewer_174191537193227, {}, function() {
# viewer_174191537193227.zoomTo();
# 	viewer_174191537193227.setStyle({"cartoon": {"color": "spectrum"}});
# viewer_174191537193227.render();
# })
# });
# </script>
